# %%
import sys
sys.path.append("../..")

# %%
from api.design import Design
design=Design()

# %%
design.generate_qubits(num=64)

# %%
design.generate_chip(qubits=True)

# %%
from addict import Dict
options = Dict(
    name="ControlLineWidthDiff0",
    type="ChargeLine",
    chip="chip0",
    path=[(-4300, 800), (-3800, 800), (-3800, -2000), (-1700, -2000), (-1700, -700), (-1700, -220)],
    width=[15, 10],
    gap=[5, 4],
    buffer_length=100,
    corner_radius=100
)
design.gds.control_lines.add(options)

# %%
design.gds.show_svg()
design.gds.get_gds_bounding_box()
# Out:
# svg文件保存在：./svg/Gds.svg
# ((-2000.5, -2000.5), (16000.5, 16000.5))
