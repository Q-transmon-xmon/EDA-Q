# %% [markdown]
# ## 本文件支持的版本：v5.6.0

# %%
import sys
sys.path.append("../..")
from api.design import Design

# %%
design = Design(qasm_path = "../../qasm_files/dj_indep_qiskit_8.qasm")
# design.generate_topology(qasm_path = "..\qasm_files\dj_indep_qiskit_8.qasm", col=3, row=3)
# Out:
# 生成耦合度矩阵...
# 耦合度矩阵的heatmap保存在./qasm_relevant_files/matrix.png
# 遗传算法迭代...
# 默认拓扑的行数为3，列数为3
# 迭代信息保存在./excel/dj_indep_qiskit_8_GATS.xls
# 适应度收敛结果保存在./qasm_relevant_files/topo_convergence.png

# %%
design.topology.show_image()

# %%
design.generate_qubits(topology=True, 
                       qubits_type="Transmon")
# design.generate_coupling_lines(topology=True, 
#                                qubits=True, 
#                                cpls_type="CouplingLineStraight")
# design.generate_chip(qubits=True, 
#                      chip_name="chip0")

# %%
design.gds.draw_gds()
design.gds.get_gds_bounding_box()
design.gds.show_svg(width=300)
# Out:
# svg文件保存在：./svg/Gds.svg
