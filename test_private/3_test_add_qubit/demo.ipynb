# %%
import sys
sys.path.append("../..")

# %%
from api.design import Design
design=Design()

# %%
from addict import Dict
options = Dict(
    name = "q0",
    type="Transmon"
)
design.gds.qubits.add(options)

# %%
design.gds.show_svg()
# Out:
# svg文件保存在：./svg/Gds.svg
