# %%
import sys
sys.path.append("../..")
from api.design import Design
from addict import Dict

# %%
from api.design import Design
design = Design()
design.topology.generate_topology1(num_rows=4, num_cols=4)
design.topology.generate_full_edges()

# %%
design.topology.show_image()

# %%
design.topology.positions
# Out:
# {'q0': (0, 0),
#  'q1': (1, 0),
#  'q2': (2, 0),
#  'q3': (3, 0),
#  'q4': (0, 1),
#  'q5': (1, 1),
#  'q6': (2, 1),
#  'q7': (3, 1),
#  'q8': (0, 2),
#  'q9': (1, 2),
#  'q10': (2, 2),
#  'q11': (3, 2),
#  'q12': (0, 3),
#  'q13': (1, 3),
#  'q14': (2, 3),
#  'q15': (3, 3)}

# %%
design.topology.positions['q0'] = (-1, 0)

# %%
design.topology.show_image()
